# %%
import numpy as np
import os
import sys       
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy
import pickle

# Get the path of the parent_directory
current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
bin_dir = parent_dir + "/data/raw/bin_files"
csv_dir = parent_dir + "/data/raw/excel_files"
sys.path.append(parent_dir)

# For .bin patch parsing
from patch.Processing.processECG import process_ECG
from patch.Processing.processPPG import process_PPG, select_ppg_array, extract_PPG_fiducial
from patch.Processing.processSCG import process_SCG, extract_SCG_fiducials
from patch.Tools.preprocessing import get_filt_dict, dict_interpolation
from patch.Tools.pipelineConfig import *
from patch.Tools.patchParser import get_newest_patch_file, parse_file

# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bin_file_paths = []

csv_file_paths = os.listdir(csv_dir)
csv_file_paths = [csv_dir + '/' + s for s in csv_file_paths]

for i in range(len(csv_file_paths)):
    if csv_file_paths[i][-1] == 's':
        del csv_file_paths[i]
        break

for i in range(len(csv_file_paths)):
    bin_file_paths.append(bin_dir + "/" + os.path.basename(os.path.normpath(csv_file_paths[i]))[3:] + ".bin")

# %%
skip_sub = [0,1,2,3,4,5,6,7,8]

for i in range(len(bin_file_paths)):
    if i in skip_sub:
        continue
    print("i = " + str(i))
    print("Processing: " + bin_file_paths[i])
    print("Processing: " + csv_file_paths[i])
    
    # Parsing raw bin file into raw_dict
    raw_dict = parse_file(bin_file_paths[i])
    
    # Interpolation, resampling, filtering
    patch_dict = dict_interpolation(raw_dict, fs_resample=FS_RESAMPLE)
    patch_filt_dict = get_filt_dict(patch_dict, FILT_ECG, FILT_SCG, FILT_PPG, Fs=FS_RESAMPLE)
    
    # Reading in timestamps of activities
    df_timestamps = pd.read_csv(csv_file_paths[i] + '/df_timestamps.csv')
    
    # Changing timestamps to 0
    df_timestamps['timestamp'] = df_timestamps['timestamp'] - df_timestamps['timestamp'][0]
    
    if len(df_timestamps['timestamp']) < 10:
        continue
    
    # Indicies for start and stop times (index loc) of activities
    rest_2_start = next(x for x, val in enumerate(patch_filt_dict['time']) if val > df_timestamps['timestamp'][3])
    rest_2_end = next(x for x, val in enumerate(patch_filt_dict['time']) if val > df_timestamps['timestamp'][4])
    script_start = next(x for x, val in enumerate(patch_filt_dict['time']) if val > df_timestamps['timestamp'][5])
    script_end = next(x for x, val in enumerate(patch_filt_dict['time']) if val > df_timestamps['timestamp'][5] + 120)
    prep_start = next(x for x, val in enumerate(patch_filt_dict['time']) if val > df_timestamps['timestamp'][6])
    prep_end = next(x for x, val in enumerate(patch_filt_dict['time']) if val > df_timestamps['timestamp'][6] + 120)
    speaking_start = next(x for x, val in enumerate(patch_filt_dict['time']) if val > df_timestamps['timestamp'][7])
    speaking_end = next(x for x, val in enumerate(patch_filt_dict['time']) if val > df_timestamps['timestamp'][8])
    recovery_start = next(x for x, val in enumerate(patch_filt_dict['time']) if val > df_timestamps['timestamp'][9])
    recovery_end = next(x for x, val in enumerate(patch_filt_dict['time']) if val > df_timestamps['timestamp'][9] + 1200)
    
    # Segmenting filtered dict
    rest_2 = {key: patch_filt_dict[key][rest_2_start:rest_2_end] for key in patch_filt_dict.keys()}
    script = {key: patch_filt_dict[key][script_start:script_end] for key in patch_filt_dict.keys()}
    prep = {key: patch_filt_dict[key][prep_start:prep_end] for key in patch_filt_dict.keys()}
    speaking = {key: patch_filt_dict[key][speaking_start:speaking_end] for key in patch_filt_dict.keys()}
    recovery = {key: patch_filt_dict[key][recovery_start:recovery_end] for key in patch_filt_dict.keys()}
    
    activities = [rest_2,script,prep,speaking,recovery]  
    act_titles = ['rest_2','script','prep','speaking','recovery']
    
    save_dir = parent_dir + "/data/interim/parse_filtered"
    if not os.path.exists(save_dir + f"/{os.path.basename(os.path.normpath(csv_file_paths[i]))[3:]}"):
        os.makedirs(save_dir + f"/{os.path.basename(os.path.normpath(csv_file_paths[i]))[3:]}")
        
    for j in range(len(activities)):
        with open (f"{save_dir}/{os.path.basename(os.path.normpath(csv_file_paths[i]))[3:]}/{act_titles[j]}.pkl", "wb") as f:
            pickle.dump(activities[j], f)
# Out:
# i = 9
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/6049.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub6049
# Device name: HP-0247
# Last sync time: Thu May 19 13:22:18 2022 UTC
# Accel Size: 18545966
# PPG Size: 1212444
# ECG Size: 9152336
# Environmental Size: 37091
# AST Time Length: 18316.512451171875
# 179649748 100.0% done
#
# STATS:
# Measurement Length: 18316.43 seconds
# File Size: 179650.048 kbytes
# Average data rate: 9808.14 bytes/second
# Theoretical uncompressed data rate: 17365.66 bytes/second
# PPG is 12.15% of the data
# ECG is 12.64% of the data
# Accel is 50.35% of the data
# Environmental is 0.14% of the data
# AST is 10.35% of the data
# Data Flag is 10.32% of the data
# time ellapsed: 38.756 seconds
# parse speed: 4635463.512 bytes/second
# parse speed: 472.614 dataSeconds/second
# i = 10
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/6048.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub6048
# Device name: HP-0247
# Last sync time: Thu May  5 12:34:57 2022 UTC
# Accel Size: 17270504
# PPG Size: 1130073
# ECG Size: 8523379
# Environmental Size: 34540
# AST Time Length: 17056.803466796875
# 167853329 100.0% done
#
# STATS:
# Measurement Length: 17056.72 seconds
# File Size: 167853.568 kbytes
# Average data rate: 9840.9 bytes/second
# Theoretical uncompressed data rate: 17366.87 bytes/second
# PPG is 12.12% of the data
# ECG is 13.03% of the data
# Accel is 50.06% of the data
# Environmental is 0.14% of the data
# AST is 10.32% of the data
# Data Flag is 10.29% of the data
# time ellapsed: 31.474 seconds
# parse speed: 5333156.465 bytes/second
# parse speed: 541.938 dataSeconds/second
# i = 11
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3154.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3154
# Device name: HP-0247
# Last sync time: Thu Jul  7 13:04:00 2022 UTC
# Accel Size: 18663194
# PPG Size: 1219809
# ECG Size: 9211015
# Environmental Size: 37325
# AST Time Length: 18432.288818359375
# 178420963 100.0% done
#
# STATS:
# Measurement Length: 18432.21 seconds
# File Size: 178421.248 kbytes
# Average data rate: 9679.86 bytes/second
# Theoretical uncompressed data rate: 17365.54 bytes/second
# PPG is 12.31% of the data
# ECG is 12.38% of the data
# Accel is 50.12% of the data
# Environmental is 0.15% of the data
# AST is 10.49% of the data
# Data Flag is 10.46% of the data
# time ellapsed: 34.258 seconds
# parse speed: 5208128.834 bytes/second
# parse speed: 538.037 dataSeconds/second
# i = 12
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3150.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3150
# Device name: HP-0247
# Last sync time: Thu Jun 23 13:22:05 2022 UTC
# Accel Size: 25053315
# PPG Size: 1647783
# ECG Size: 12366721
# Environmental Size: 50105
# AST Time Length: 24742.87353515625
# 248462542 100.0% done
#
# STATS:
# Measurement Length: 24742.79 seconds
# File Size: 248462.848 kbytes
# Average data rate: 10041.83 bytes/second
# Theoretical uncompressed data rate: 17373.68 bytes/second
# PPG is 11.94% of the data
# ECG is 13.24% of the data
# Accel is 50.51% of the data
# Environmental is 0.14% of the data
# AST is 10.11% of the data
# Data Flag is 10.08% of the data
# time ellapsed: 46.874 seconds
# parse speed: 5300700.769 bytes/second
# parse speed: 527.862 dataSeconds/second
# i = 13
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3135.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3135
# Device name: HP-0247
# Last sync time: Tue Apr 26 13:28:23 2022 UTC
# Accel Size: 20385516
# PPG Size: 1338703
# ECG Size: 10063568
# Environmental Size: 40770
# AST Time Length: 20131.918212890625
# 198081732 100.0% done
#
# STATS:
# Measurement Length: 20131.84 seconds
# File Size: 198082.048 kbytes
# Average data rate: 9839.24 bytes/second
# Theoretical uncompressed data rate: 17372.89 bytes/second
# PPG is 12.16% of the data
# ECG is 13.88% of the data
# Accel is 49.14% of the data
# Environmental is 0.14% of the data
# AST is 10.32% of the data
# Data Flag is 10.29% of the data
# time ellapsed: 37.920 seconds
# parse speed: 5223682.263 bytes/second
# parse speed: 530.903 dataSeconds/second
# i = 14
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3130.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3130
# Device name: HP-0022
# Last sync time: Tue Mar 29 13:25:35 2022 UTC
# Accel Size: 23344926
# PPG Size: 1534750
# ECG Size: 11614370
# Environmental Size: 46689
# AST Time Length: 23253.655029296875
# 241089741 100.0% done
#
# STATS:
# Measurement Length: 23253.57 seconds
# File Size: 241090.048 kbytes
# Average data rate: 10367.87 bytes/second
# Theoretical uncompressed data rate: 17240.87 bytes/second
# PPG is 11.46% of the data
# ECG is 14.04% of the data
# Accel is 51.16% of the data
# Environmental is 0.14% of the data
# AST is 9.71% of the data
# Data Flag is 9.68% of the data
# time ellapsed: 44.572 seconds
# parse speed: 5408976.924 bytes/second
# parse speed: 521.706 dataSeconds/second
# i = 15
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3137.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3137
# Device name: HP-0247
# Last sync time: Mon May  2 13:56:33 2022 UTC
# Accel Size: 17437022
# PPG Size: 1140858
# ECG Size: 8606368
# Environmental Size: 34873
# AST Time Length: 17221.361328125
# 175553768 100.0% done
#
# STATS:
# Measurement Length: 17221.28 seconds
# File Size: 175554.048 kbytes
# Average data rate: 10194.02 bytes/second
# Theoretical uncompressed data rate: 17366.84 bytes/second
# PPG is 11.7% of the data
# ECG is 13.81% of the data
# Accel is 50.56% of the data
# Environmental is 0.14% of the data
# AST is 9.96% of the data
# Data Flag is 9.93% of the data
# time ellapsed: 32.984 seconds
# parse speed: 5322349.725 bytes/second
# parse speed: 522.105 dataSeconds/second
# i = 16
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3152.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3152
# Device name: HP-0247
# Last sync time: Tue Jun 28 13:02:38 2022 UTC
# Accel Size: 24487927
# PPG Size: 1600789
# ECG Size: 12085171
# Environmental Size: 48975
# AST Time Length: 24184.6396484375
# 240925891 100.0% done
#
# STATS:
# Measurement Length: 24184.56 seconds
# File Size: 240926.208 kbytes
# Average data rate: 9961.99 bytes/second
# Theoretical uncompressed data rate: 17365.87 bytes/second
# PPG is 11.96% of the data
# ECG is 13.86% of the data
# Accel is 49.69% of the data
# Environmental is 0.14% of the data
# AST is 10.19% of the data
# Data Flag is 10.16% of the data
# time ellapsed: 45.739 seconds
# parse speed: 5267377.731 bytes/second
# parse speed: 528.748 dataSeconds/second
# i = 17
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3141.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3141
# Device name: HP-0247
# Last sync time: Mon May 16 13:05:40 2022 UTC
# Accel Size: 22303217
# PPG Size: 1456243
# ECG Size: 11008850
# Environmental Size: 44605
# AST Time Length: 22025.925048828125
# 223476989 100.0% done
#
# STATS:
# Measurement Length: 22025.84 seconds
# File Size: 223477.248 kbytes
# Average data rate: 10146.14 bytes/second
# Theoretical uncompressed data rate: 17365.64 bytes/second
# PPG is 11.73% of the data
# ECG is 13.71% of the data
# Accel is 50.52% of the data
# Environmental is 0.14% of the data
# AST is 10.01% of the data
# Data Flag is 9.98% of the data
# time ellapsed: 41.998 seconds
# parse speed: 5321187.169 bytes/second
# parse speed: 524.454 dataSeconds/second
# i = 18
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3136.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3136
# Device name: HP-0247
# Last sync time: Thu Apr 28 12:48:22 2022 UTC
# Accel Size: 27064243
# PPG Size: 1771791
# ECG Size: 13362129
# Environmental Size: 54127
# AST Time Length: 26728.093017578125
# 270171333 100.0% done
#
# STATS:
# Measurement Length: 26728.01 seconds
# File Size: 270171.648 kbytes
# Average data rate: 10108.18 bytes/second
# Theoretical uncompressed data rate: 17369.05 bytes/second
# PPG is 11.8% of the data
# ECG is 14.75% of the data
# Accel is 49.31% of the data
# Environmental is 0.14% of the data
# AST is 10.04% of the data
# Data Flag is 10.02% of the data
# time ellapsed: 50.764 seconds
# parse speed: 5322067.391 bytes/second
# parse speed: 526.511 dataSeconds/second
# i = 19
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3128.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3128
# Device name: HP-0022
# Last sync time: Thu Mar 24 12:36:12 2022 UTC
# Accel Size: 24931353
# PPG Size: 1640350
# ECG Size: 12407100
# Environmental Size: 49861
# AST Time Length: 24832.83837890625
# 249199861 100.0% done
#
# STATS:
# Measurement Length: 24832.76 seconds
# File Size: 249200.128 kbytes
# Average data rate: 10035.14 bytes/second
# Theoretical uncompressed data rate: 17243.1 bytes/second
# PPG is 11.85% of the data
# ECG is 14.37% of the data
# Accel is 49.65% of the data
# Environmental is 0.14% of the data
# AST is 10.03% of the data
# Data Flag is 10.0% of the data
# time ellapsed: 46.789 seconds
# parse speed: 5326030.699 bytes/second
# parse speed: 530.738 dataSeconds/second
# i = 20
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3133.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3133
# Device name: HP-0247
# Last sync time: Thu Apr 21 13:16:07 2022 UTC
# Accel Size: 24609048
# PPG Size: 1607516
# ECG Size: 12145658
# Environmental Size: 49218
# AST Time Length: 24304.418212890625
# 252476570 100.0% done
#
# STATS:
# Measurement Length: 24304.34 seconds
# File Size: 252476.928 kbytes
# Average data rate: 10388.14 bytes/second
# Theoretical uncompressed data rate: 17364.99 bytes/second
# PPG is 11.46% of the data
# ECG is 14.0% of the data
# Accel is 51.06% of the data
# Environmental is 0.14% of the data
# AST is 9.77% of the data
# Data Flag is 9.75% of the data
# time ellapsed: 46.475 seconds
# parse speed: 5432506.192 bytes/second
# parse speed: 522.953 dataSeconds/second
# i = 21
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3157.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3157
# Device name: HP-0247
# Last sync time: Tue Jul 19 13:11:25 2022 UTC
# Accel Size: 22125609
# PPG Size: 1444289
# ECG Size: 10921613
# Environmental Size: 44250
# AST Time Length: 21851.52734375
# 219708653 100.0% done
#
# STATS:
# Measurement Length: 21851.45 seconds
# File Size: 219708.928 kbytes
# Average data rate: 10054.66 bytes/second
# Theoretical uncompressed data rate: 17364.63 bytes/second
# PPG is 11.83% of the data
# ECG is 13.27% of the data
# Accel is 50.64% of the data
# Environmental is 0.14% of the data
# AST is 10.1% of the data
# Data Flag is 10.07% of the data
# time ellapsed: 41.352 seconds
# parse speed: 5313131.532 bytes/second
# parse speed: 528.425 dataSeconds/second
# i = 22
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/6050.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub6050
# Device name: HP-0247
# Last sync time: Tue Jun 14 13:33:56 2022 UTC
# Accel Size: 17196680
# PPG Size: 1123246
# ECG Size: 8487690
# Environmental Size: 34392
# AST Time Length: 16983.8408203125
# 168918248 100.0% done
#
# STATS:
# Measurement Length: 16983.76 seconds
# File Size: 168918.528 kbytes
# Average data rate: 9945.89 bytes/second
# Theoretical uncompressed data rate: 17364.98 bytes/second
# PPG is 11.97% of the data
# ECG is 13.77% of the data
# Accel is 49.74% of the data
# Environmental is 0.14% of the data
# AST is 10.21% of the data
# Data Flag is 10.18% of the data
# time ellapsed: 32.028 seconds
# parse speed: 5274089.545 bytes/second
# parse speed: 530.278 dataSeconds/second
# i = 23
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3156.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3156
# Device name: HP-0247
# Last sync time: Mon Jul 18 13:09:18 2022 UTC
# Accel Size: 22495051
# PPG Size: 1473254
# ECG Size: 11102719
# Environmental Size: 44989
# AST Time Length: 22216.098388671875
# 219217107 100.0% done
#
# STATS:
# Measurement Length: 22216.02 seconds
# File Size: 219217.408 kbytes
# Average data rate: 9867.54 bytes/second
# Theoretical uncompressed data rate: 17368.56 bytes/second
# PPG is 12.1% of the data
# ECG is 13.18% of the data
# Accel is 50.0% of the data
# Environmental is 0.14% of the data
# AST is 10.29% of the data
# Data Flag is 10.26% of the data
# time ellapsed: 41.855 seconds
# parse speed: 5237540.063 bytes/second
# parse speed: 530.785 dataSeconds/second
# i = 24
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3159.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3159
# Device name: HP-0247
# Last sync time: Mon Jul 25 13:08:42 2022 UTC
# Accel Size: 20304519
# PPG Size: 1327069
# ECG Size: 10021144
# Environmental Size: 40608
# AST Time Length: 20052.75048828125
# 202341596 100.0% done
#
# STATS:
# Measurement Length: 20052.67 seconds
# File Size: 202341.888 kbytes
# Average data rate: 10090.52 bytes/second
# Theoretical uncompressed data rate: 17366.02 bytes/second
# PPG is 11.81% of the data
# ECG is 13.24% of the data
# Accel is 50.78% of the data
# Environmental is 0.14% of the data
# AST is 10.06% of the data
# Data Flag is 10.03% of the data
# time ellapsed: 38.014 seconds
# parse speed: 5322818.416 bytes/second
# parse speed: 527.507 dataSeconds/second
# i = 25
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3146.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3146
# Device name: HP-0247
# Last sync time: Tue Jun  7 13:05:51 2022 UTC
# Accel Size: 20385425
# PPG Size: 1336711
# ECG Size: 10060496
# Environmental Size: 40770
# AST Time Length: 20133.77490234375
# 194804836 100.0% done
#
# STATS:
# Measurement Length: 20133.69 seconds
# File Size: 194805.248 kbytes
# Average data rate: 9675.58 bytes/second
# Theoretical uncompressed data rate: 17368.83 bytes/second
# PPG is 12.35% of the data
# ECG is 13.15% of the data
# Accel is 49.28% of the data
# Environmental is 0.15% of the data
# AST is 10.49% of the data
# Data Flag is 10.46% of the data
# time ellapsed: 37.606 seconds
# parse speed: 5180139.852 bytes/second
# parse speed: 535.383 dataSeconds/second
# i = 26
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/6047.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub6047
# Device name: HP-0247
# Last sync time: Fri Apr 15 13:08:34 2022 UTC
# Accel Size: 23445631
# PPG Size: 1534050
# ECG Size: 11572845
# Environmental Size: 46890
# AST Time Length: 23155.255615234375
# 230194378 100.0% done
#
# STATS:
# Measurement Length: 23155.17 seconds
# File Size: 230194.688 kbytes
# Average data rate: 9941.39 bytes/second
# Theoretical uncompressed data rate: 17367.31 bytes/second
# PPG is 12.0% of the data
# ECG is 13.36% of the data
# Accel is 50.1% of the data
# Environmental is 0.14% of the data
# AST is 10.21% of the data
# Data Flag is 10.19% of the data
# time ellapsed: 44.209 seconds
# parse speed: 5206967.450 bytes/second
# parse speed: 523.766 dataSeconds/second
# i = 27
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3151.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3151
# Device name: HP-0247
# Last sync time: Mon Jun 27 14:06:52 2022 UTC
# Accel Size: 22445694
# PPG Size: 1468840
# ECG Size: 11077918
# Environmental Size: 44890
# AST Time Length: 22167.686279296875
# 221756630 100.0% done
#
# STATS:
# Measurement Length: 22167.61 seconds
# File Size: 221756.928 kbytes
# Average data rate: 10003.65 bytes/second
# Theoretical uncompressed data rate: 17367.26 bytes/second
# PPG is 11.92% of the data
# ECG is 14.68% of the data
# Accel is 49.01% of the data
# Environmental is 0.14% of the data
# AST is 10.15% of the data
# Data Flag is 10.12% of the data
# time ellapsed: 41.385 seconds
# parse speed: 5358448.870 bytes/second
# parse speed: 535.649 dataSeconds/second
# i = 28
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3158.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3158
# Device name: HP-0247
# Last sync time: Thu Jul 21 13:00:48 2022 UTC
# Accel Size: 23710955
# PPG Size: 1550232
# ECG Size: 11702256
# Environmental Size: 47421
# AST Time Length: 23418.015380859375
# 231423208 100.0% done
#
# STATS:
# Measurement Length: 23417.93 seconds
# File Size: 231423.488 kbytes
# Average data rate: 9882.32 bytes/second
# Theoretical uncompressed data rate: 17365.6 bytes/second
# PPG is 12.06% of the data
# ECG is 13.15% of the data
# Accel is 50.11% of the data
# Environmental is 0.14% of the data
# AST is 10.27% of the data
# Data Flag is 10.25% of the data
# time ellapsed: 49.884 seconds
# parse speed: 4639215.324 bytes/second
# parse speed: 469.446 dataSeconds/second
# i = 29
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3161.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3161
# Device name: HP-0247
# Last sync time: Thu Jul 28 13:57:25 2022 UTC
# Accel Size: 20686840
# PPG Size: 1353086
# ECG Size: 10209626
# Environmental Size: 41372
# AST Time Length: 20431.12353515625
# 210042072 100.0% done
#
# STATS:
# Measurement Length: 20431.04 seconds
# File Size: 210042.368 kbytes
# Average data rate: 10280.55 bytes/second
# Theoretical uncompressed data rate: 17366.21 bytes/second
# PPG is 11.6% of the data
# ECG is 13.41% of the data
# Accel is 51.27% of the data
# Environmental is 0.14% of the data
# AST is 9.88% of the data
# Data Flag is 9.85% of the data
# time ellapsed: 38.423 seconds
# parse speed: 5466530.255 bytes/second
# parse speed: 531.735 dataSeconds/second
# i = 30
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3145.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3145
# Device name: HP-0247
# Last sync time: Tue May 31 13:01:42 2022 UTC
# Accel Size: 22393976
# PPG Size: 1464000
# ECG Size: 11053588
# Environmental Size: 44787
# AST Time Length: 22116.43994140625
# 222575848 100.0% done
#
# STATS:
# Measurement Length: 22116.36 seconds
# File Size: 222576.128 kbytes
# Average data rate: 10063.87 bytes/second
# Theoretical uncompressed data rate: 17366.42 bytes/second
# PPG is 11.84% of the data
# ECG is 14.22% of the data
# Accel is 49.71% of the data
# Environmental is 0.14% of the data
# AST is 10.09% of the data
# Data Flag is 10.06% of the data
# time ellapsed: 41.737 seconds
# parse speed: 5332868.705 bytes/second
# parse speed: 529.902 dataSeconds/second
# i = 31
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3149.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3149
# Device name: HP-0247
# Last sync time: Thu Jun 16 13:25:25 2022 UTC
# Accel Size: 21690578
# PPG Size: 1418573
# ECG Size: 10705206
# Environmental Size: 43380
# AST Time Length: 21422.10107421875
# 213974251 100.0% done
#
# STATS:
# Measurement Length: 21422.02 seconds
# File Size: 213974.528 kbytes
# Average data rate: 9988.53 bytes/second
# Theoretical uncompressed data rate: 17366.39 bytes/second
# PPG is 11.93% of the data
# ECG is 13.26% of the data
# Accel is 50.38% of the data
# Environmental is 0.14% of the data
# AST is 10.16% of the data
# Data Flag is 10.14% of the data
# time ellapsed: 50.415 seconds
# parse speed: 4244221.992 bytes/second
# parse speed: 424.909 dataSeconds/second
# i = 32
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3155.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3155
# Device name: HP-0247
# Last sync time: Tue Jul 12 12:59:38 2022 UTC
# Accel Size: 21162028
# PPG Size: 1381476
# ECG Size: 10446177
# Environmental Size: 42323
# AST Time Length: 20899.591064453125
# 207420626 100.0% done
#
# STATS:
# Measurement Length: 20899.51 seconds
# File Size: 207420.928 kbytes
# Average data rate: 9924.68 bytes/second
# Theoretical uncompressed data rate: 17364.98 bytes/second
# PPG is 11.99% of the data
# ECG is 13.02% of the data
# Accel is 50.42% of the data
# Environmental is 0.14% of the data
# AST is 10.23% of the data
# Data Flag is 10.2% of the data
# time ellapsed: 50.116 seconds
# parse speed: 4138856.462 bytes/second
# parse speed: 417.027 dataSeconds/second
# i = 33
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3143.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3143
# Device name: HP-0247
# Last sync time: Mon May 23 12:59:22 2022 UTC
# Accel Size: 23392558
# PPG Size: 1529204
# ECG Size: 11548162
# Environmental Size: 46784
# AST Time Length: 23100.409912109375
# 225361097 100.0% done
#
# STATS:
# Measurement Length: 23100.33 seconds
# File Size: 225361.408 kbytes
# Average data rate: 9755.77 bytes/second
# Theoretical uncompressed data rate: 17368.33 bytes/second
# PPG is 12.21% of the data
# ECG is 13.02% of the data
# Accel is 49.76% of the data
# Environmental is 0.15% of the data
# AST is 10.41% of the data
# Data Flag is 10.38% of the data
# time ellapsed: 54.867 seconds
# parse speed: 4107437.346 bytes/second
# parse speed: 421.027 dataSeconds/second
# i = 34
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3162.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3162
# Device name: HP-0247
# Last sync time: Mon Aug  1 14:01:21 2022 UTC
# Accel Size: 21284944
# PPG Size: 1391325
# ECG Size: 10505769
# Environmental Size: 42569
# AST Time Length: 21020.681884765625
# 217087162 100.0% done
#
# STATS:
# Measurement Length: 21020.6 seconds
# File Size: 217087.488 kbytes
# Average data rate: 10327.37 bytes/second
# Theoretical uncompressed data rate: 17366.59 bytes/second
# PPG is 11.54% of the data
# ECG is 13.42% of the data
# Accel is 51.42% of the data
# Environmental is 0.14% of the data
# AST is 9.83% of the data
# Data Flag is 9.8% of the data
# time ellapsed: 51.914 seconds
# parse speed: 4181656.543 bytes/second
# parse speed: 404.910 dataSeconds/second
# i = 35
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3132.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3132
# Device name: HP-0247
# Last sync time: Tue Apr 19 13:50:17 2022 UTC
# Accel Size: 23768199
# PPG Size: 1553463
# ECG Size: 11733355
# Environmental Size: 47535
# AST Time Length: 23473.173828125
# 241663173 100.0% done
#
# STATS:
# Measurement Length: 23473.09 seconds
# File Size: 241663.488 kbytes
# Average data rate: 10295.34 bytes/second
# Theoretical uncompressed data rate: 17366.72 bytes/second
# PPG is 11.57% of the data
# ECG is 14.39% of the data
# Accel is 50.35% of the data
# Environmental is 0.14% of the data
# AST is 9.86% of the data
# Data Flag is 9.84% of the data
# time ellapsed: 57.495 seconds
# parse speed: 4203178.325 bytes/second
# parse speed: 408.260 dataSeconds/second
# i = 36
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/6044.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub6044
# Device name: HP-0022
# Last sync time: Mon Mar 21 12:59:04 2022 UTC
# Accel Size: 19203041
# PPG Size: 1261542
# ECG Size: 9555101
# Environmental Size: 38405
# AST Time Length: 19127.73193359375
# 192101583 100.0% done
#
# STATS:
# Measurement Length: 19127.65 seconds
# File Size: 192101.888 kbytes
# Average data rate: 10043.15 bytes/second
# Theoretical uncompressed data rate: 17240.53 bytes/second
# PPG is 11.82% of the data
# ECG is 13.96% of the data
# Accel is 50.12% of the data
# Environmental is 0.14% of the data
# AST is 10.02% of the data
# Data Flag is 10.0% of the data
# time ellapsed: 46.174 seconds
# parse speed: 4160364.315 bytes/second
# parse speed: 414.249 dataSeconds/second
# i = 37
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/6045.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub6045
# Device name: HP-0022
# Last sync time: Tue Mar 22 12:53:05 2022 UTC
# Accel Size: 25327627
# PPG Size: 1662473
# ECG Size: 12604872
# Environmental Size: 50654
# AST Time Length: 25227.763671875
# 254852309 100.0% done
#
# STATS:
# Measurement Length: 25227.68 seconds
# File Size: 254852.608 kbytes
# Average data rate: 10102.1 bytes/second
# Theoretical uncompressed data rate: 17240.22 bytes/second
# PPG is 11.74% of the data
# ECG is 14.62% of the data
# Accel is 49.68% of the data
# Environmental is 0.14% of the data
# AST is 9.97% of the data
# Data Flag is 9.94% of the data
# time ellapsed: 60.571 seconds
# parse speed: 4207475.169 bytes/second
# parse speed: 416.495 dataSeconds/second
# i = 38
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3163.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3163
# Device name: HP-0247
# Last sync time: Tue Aug  2 13:11:07 2022 UTC
# Accel Size: 23785574
# PPG Size: 1555157
# ECG Size: 11741687
# Environmental Size: 47570
# AST Time Length: 23489.29931640625
# 227081477 100.0% done
#
# STATS:
# Measurement Length: 23489.22 seconds
# File Size: 227081.728 kbytes
# Average data rate: 9667.49 bytes/second
# Theoretical uncompressed data rate: 17367.87 bytes/second
# PPG is 12.33% of the data
# ECG is 12.9% of the data
# Accel is 49.54% of the data
# Environmental is 0.15% of the data
# AST is 10.5% of the data
# Data Flag is 10.47% of the data
# time ellapsed: 55.802 seconds
# parse speed: 4069447.724 bytes/second
# parse speed: 420.942 dataSeconds/second
# i = 39
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3142.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3142
# Device name: HP-0247
# Last sync time: Tue May 17 13:14:19 2022 UTC
# Accel Size: 28472867
# PPG Size: 1864860
# ECG Size: 14057405
# Environmental Size: 56944
# AST Time Length: 28118.708251953125
# 284015824 100.0% done
#
# STATS:
# Measurement Length: 28118.63 seconds
# File Size: 284016.128 kbytes
# Average data rate: 10100.64 bytes/second
# Theoretical uncompressed data rate: 17369.88 bytes/second
# PPG is 11.82% of the data
# ECG is 14.23% of the data
# Accel is 49.79% of the data
# Environmental is 0.14% of the data
# AST is 10.05% of the data
# Data Flag is 10.03% of the data
# time ellapsed: 68.351 seconds
# parse speed: 4155248.549 bytes/second
# parse speed: 411.385 dataSeconds/second
# i = 40
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3147.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3147
# Device name: HP-0247
# Last sync time: Thu Jun  9 13:26:41 2022 UTC
# Accel Size: 22047302
# PPG Size: 1439537
# ECG Size: 10881448
# Environmental Size: 44093
# AST Time Length: 21773.192138671875
# 218479863 100.0% done
#
# STATS:
# Measurement Length: 21773.11 seconds
# File Size: 218480.128 kbytes
# Average data rate: 10034.4 bytes/second
# Theoretical uncompressed data rate: 17365.44 bytes/second
# PPG is 11.86% of the data
# ECG is 14.09% of the data
# Accel is 49.74% of the data
# Environmental is 0.14% of the data
# AST is 10.12% of the data
# Data Flag is 10.09% of the data
# time ellapsed: 52.562 seconds
# parse speed: 4156637.161 bytes/second
# parse speed: 414.239 dataSeconds/second
# i = 41
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3139.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3139
# Device name: HP-0247
# Last sync time: Tue May 10 13:02:18 2022 UTC
# Accel Size: 22302217
# PPG Size: 1470189
# ECG Size: 11007573
# Environmental Size: 44604
# AST Time Length: 22025.98828125
# 228310237 100.0% done
#
# STATS:
# Measurement Length: 22025.91 seconds
# File Size: 228310.528 kbytes
# Average data rate: 10365.54 bytes/second
# Theoretical uncompressed data rate: 17376.12 bytes/second
# PPG is 11.59% of the data
# ECG is 14.86% of the data
# Accel is 49.99% of the data
# Environmental is 0.14% of the data
# AST is 9.8% of the data
# Data Flag is 9.77% of the data
# time ellapsed: 53.754 seconds
# parse speed: 4247295.036 bytes/second
# parse speed: 409.751 dataSeconds/second
# i = 42
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3131.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3131
# Device name: HP-0247
# Last sync time: Tue Apr  5 12:57:38 2022 UTC
# Accel Size: 22137050
# PPG Size: 1448040
# ECG Size: 10926219
# Environmental Size: 44273
# AST Time Length: 21863.53271484375
# 221674698 100.0% done
#
# STATS:
# Measurement Length: 21863.45 seconds
# File Size: 221675.008 kbytes
# Average data rate: 10139.07 bytes/second
# Theoretical uncompressed data rate: 17366.35 bytes/second
# PPG is 11.76% of the data
# ECG is 13.78% of the data
# Accel is 50.4% of the data
# Environmental is 0.14% of the data
# AST is 10.01% of the data
# Data Flag is 9.99% of the data
# time ellapsed: 43.404 seconds
# parse speed: 5107199.545 bytes/second
# parse speed: 503.715 dataSeconds/second
# i = 43
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/bin_files/3138.bin
# Processing: /home/michael/Code/mims-transformer-stress-classification/data/raw/excel_files/sub3138
# Device name: HP-0247
# Last sync time: Mon May  9 13:32:10 2022 UTC
# Accel Size: 27960004
# PPG Size: 1827438
# ECG Size: 13803586
# Environmental Size: 55918
# AST Time Length: 27612.26904296875
# 276397285 100.0% done
#
# STATS:
# Measurement Length: 27612.19 seconds
# File Size: 276397.568 kbytes
# Average data rate: 10009.98 bytes/second
# Theoretical uncompressed data rate: 17367.27 bytes/second
# PPG is 11.9% of the data
# ECG is 14.27% of the data
# Accel is 49.46% of the data
# Environmental is 0.14% of the data
# AST is 10.14% of the data
# Data Flag is 10.12% of the data
# time ellapsed: 54.847 seconds
# parse speed: 5039448.457 bytes/second
# parse speed: 503.442 dataSeconds/second
