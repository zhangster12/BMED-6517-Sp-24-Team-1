# %%
import numpy as np
import os
import sys       
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy
import pickle

# Get the path of the parent_directory
current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
parse_filtered = parent_dir + "/data/interim/parse_filtered"
outputdir = parent_dir +  "/models"
figures_dir = parent_dir + "/reports/figures"
sys.path.append(parent_dir)

# For .bin patch parsing
from patch.Processing.processECG import process_ECG
from patch.Processing.processPPG import process_PPG, select_ppg_array, extract_PPG_fiducial
from patch.Processing.processSCG import process_SCG, extract_SCG_fiducials
from patch.Tools.preprocessing import get_filt_dict, dict_interpolation
from patch.Tools.pipelineConfig import *
from patch.Tools.patchParser import get_newest_patch_file, parse_file

# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %%
sub_act_paths = os.listdir(parse_filtered)
sub_act_paths = [parse_filtered + '/' + s for s in sub_act_paths]

# %%
# %matplotlib inline
act_titles = ["prep","recovery","rest_2","script","speaking"]

# Turn interactive plotting off
show_plots = False
plt.ioff()

for subject in sub_act_paths:
    prep = pickle.load(open(subject + "/prep.pkl", "rb"))
    recovery = pickle.load(open(subject + "/recovery.pkl", "rb"))
    rest_2 = pickle.load(open(subject + "/rest_2.pkl", "rb"))
    script = pickle.load(open(subject + "/script.pkl", "rb"))
    speaking = pickle.load(open(subject + "/speaking.pkl", "rb"))
    activities = [prep,recovery,rest_2,script,speaking]
    count = 0
    
    # For skipping specific subjects
    skip = False
    for sub in skip_sub:
        if sub in subject:
            skip = True
    if skip:
        continue
    
    print(f"Subject: {os.path.basename(os.path.normpath(subject))}")
    
    for activity in activities:
        # Output features directory
        out = outputdir+f'/{os.path.basename(os.path.normpath(subject))}/{act_titles[count]}/'
        
        # Output figures directory
        fig_dir = figures_dir+f'/{os.path.basename(os.path.normpath(subject))}/{act_titles[count]}/'
        
        print(f"Activity: {act_titles[count]}")
        
        count = count + 1
        
        # Creating directories that don't exist
        if not os.path.exists(out):
            os.makedirs(out)
        if not os.path.exists(fig_dir):
            os.makedirs(fig_dir)
        
        # Plotting raw signals
        fig, axs = plt.subplots(3,1, sharex=True, figsize=(12,8))
        plt.suptitle("Raw Signals")
        axs[0].plot(activity['time'], activity['ecg'], color='salmon')
        axs[1].plot(activity['time'], activity['scg_DV'], color='teal')
        axs[2].plot(activity['time'], activity['ppg_ir_2'], color='darkgreen')
        plt.savefig(fig_dir + "raw_signal.png")
        
        if show_plots:
            plt.show()

        # Note we pass the raw ECG here, as we use different R-peak detectors that each require specific filtering
        ecg_dict = process_ECG(activity['ecg'],
                        activity['time'],
                        force_inverse=False,
                        width_QRS=width_QRS,
                        peak_tol=pk_tolerance_ms, 
                        beat_len=beat_length, 
                        Fs=FS_RESAMPLE, 
                        verbose=True, 
                        plotFlag=True)
        
        # PPG Array selection
        ppg_arr,_ = select_ppg_array(activity[ppg_wavelen+'_1'], 
                                    activity[ppg_wavelen+'_2'], 
                                    verbose=True)

        # Process PPG
        ppg_dict = process_PPG(activity[ppg_wavelen+ppg_arr], 
                                activity[ppg_wavelen+ppg_arr], 
                                ecg_dict, 
                                ensembleSize=ensemble_length, 
                                useTemplateSQI=True,
                                beat_len=beat_length, 
                                Fs=FS_RESAMPLE, 
                                verbose=True)

        plt.figure(figsize=(9, 6))
        _=plt.plot(ppg_dict['ppg_beats'], color='gray', alpha=0.1)
        _=plt.plot(np.mean(ppg_dict['ppg_beats'], axis=1), color='red', alpha=0.6, lw=3)
        _=plt.savefig(fig_dir + "ppg_beats.png")
        
        # Process SCG
        scg_dict = process_SCG(activity['scg_DV'], 
                                activity['pcg_DV'], 
                                ecg_dict, 
                                ensembleSize=ensemble_length, 
                                useTemplateSQI=True,
                                beat_len=beat_length, 
                                Fs=FS_RESAMPLE, 
                                verbose=True)

        plt.figure(figsize=(12, 6))
        _=plt.plot(scg_dict['scg_beats'], color='gray', alpha=0.1)
        _=plt.plot(np.mean(scg_dict['scg_beats'], axis=1), color='red', alpha=0.6, lw=3)
        _=plt.savefig(fig_dir + "scg_beats.png")
        
        scg_fid_dict = extract_SCG_fiducials(scg_dict, 
                                    num_features_ao=4, 
                                    num_features_ac=3, 
                                    ema_factor=1.0, 
                                    verbose=True, 
                                    method = 'Template') # choose between 'GMM', 'Template', or 'Jon'

        ao_locs, ac_locs, flagged_ao, flagged_ac = np.squeeze(scg_fid_dict['ao_locs']), np.squeeze(scg_fid_dict['ac_locs']), scg_fid_dict['flagged_ao'], scg_fid_dict['flagged_ac']
        scg_beats_used = scg_fid_dict['beats_used']
        # Update these as they may have been reduced to find possible candidates
        num_feats_ao, num_feats_ac = np.shape(scg_fid_dict['ao_cands'])[0], np.shape(scg_fid_dict['ac_cands'])[0]

        # Plot results of fiducial tracking
        scg_beats = scg_dict['scg_beats'].copy()

        print(f"Least deviation ao_loc={np.argmin(np.nanstd(scg_fid_dict['ao_cands'], axis=1))}")
        if num_feats_ac > 1:
            max_idx = np.nanmax(scg_fid_dict['ac_cands'][-1].T)
            print(f"Least deviation ac_loc={np.argmin(np.nanstd(scg_fid_dict['ac_cands'], axis=1))}")
        else:
            max_idx = np.nanmax(scg_fid_dict['ac_cands'])
            print(f"Least deviation ac_loc={np.argmin(np.nanstd(scg_fid_dict['ac_cands']))}")
        scg_beats = np.ceil(255 * (scg_beats / scg_beats.max(axis=0)))

        f, ax = plt.subplots(1, 2, figsize=(14, 5))
        ax[0].imshow(scg_beats[:int(max_idx),:], cmap='gray',vmin = 0, vmax = 255, aspect='auto')
        ax[0].plot(scg_fid_dict['ao_cands'].T, color='red', alpha=0.3)
        ax[0].plot(scg_fid_dict['ac_cands'].T, color='red', alpha=0.3)
        ax[0].plot(ao_locs.T, color='blue', alpha=0.8, label = 'AO')
        ax[0].plot(ac_locs.T, color='g', alpha=0.8, label = 'AC')
        ax[0].plot(scg_fid_dict['s1_loc']*np.ones(len(scg_fid_dict['ao_locs'])), color='green', lw=3, alpha=0.2)
        ax[0].set_ylabel('Time from R-peak [samples]')
        ax[0].set_xlabel('Beats')
        ax[0].legend()

        ao_amp = [scg_dict['scg_beats'][ao_loc_i, scg_beat_idx][0] for ao_loc_i, scg_beat_idx in zip(scg_fid_dict['ao_locs'].astype(int), scg_fid_dict['flagged_ao'])]
        ac_amp = [scg_dict['scg_beats'][ac_loc_i, scg_beat_idx][0] for ac_loc_i, scg_beat_idx in zip(scg_fid_dict['ac_locs'].astype(int), scg_fid_dict['flagged_ac'])]
        ax[1].plot(scg_dict['scg_beats'], color='gray', alpha=0.1)
        ax[1].plot(np.mean(scg_dict['scg_beats'], axis=1), color='red', alpha=0.6, lw=3)
        ax[1].scatter(scg_fid_dict['ao_locs'], ao_amp, alpha = 0.3, color = 'tab:blue', label = 'AO')
        ax[1].scatter(scg_fid_dict['ac_locs'], ac_amp, alpha = 0.3, color = 'tab:green', label = 'AC')
        ax[1].set_xlabel('Time from R-peak [samples]')
        ax[1].set_ylabel('SCG amplitude')
        ax[1].legend()
        plt.savefig(fig_dir + "scg_fiducial.png")
        if show_plots:
            plt.show()
        
        ppg_fid_dict = extract_PPG_fiducial(ppg_dict, memory=30, smooth=10, max_dist_foot=max_dist_foot)

        ppg_beats = ppg_dict['ppg_beats'].copy()
        ppg_beats = np.ceil(255 * (ppg_beats / ppg_beats.max(axis=0)))

        f, ax = plt.subplots(1, 2, figsize=(14, 5))
        ax[0].imshow(ppg_beats, cmap='gray',vmin = 0, vmax = 255, aspect='auto')
        ax[0].plot(ppg_fid_dict['pulse_locs'], color='blue', alpha=0.6, label = 'PAT')
        ax[0].set_ylabel('Time from R-peak [samples]')
        ax[0].set_xlabel('Beats')
        ax[0].legend()


        ppg_pat_amp = [ppg_dict['ppg_beats'][pat_loc_i, i] for i, pat_loc_i in  enumerate(ppg_fid_dict['pulse_locs'].astype(int))]
        ax[1].plot(ppg_dict['ppg_beats'], color='gray', alpha=0.1)
        ax[1].plot(np.mean(ppg_dict['ppg_beats'], axis=1), color='red', alpha=0.6, lw=3)
        ax[1].scatter(ppg_fid_dict['pulse_locs'], ppg_pat_amp, alpha = 0.3, color = 'tab:blue', label = 'PAT')
        ax[1].set_xlabel('Time from R-peak [samples]')
        ax[1].set_ylabel('PPG amplitude')
        ax[1].legend()
        plt.savefig(fig_dir + "ppg_fiducial.png")
        if show_plots:
            plt.show()
        
        feat_df = pd.DataFrame()

        t_feats = ecg_dict['t_beats']
        feat_df['time'] = t_feats

        feat_df['hr'] = ecg_dict['hr']

        # Prerequisite check to see if greater than 5 minutes of data is present (necessary to compute all HRV features)
        if (feat_df['time'].values[-1] - feat_df['time'].values[0]) < 5*60:
            print('Not enough data for HRV analysis')
            # Frequency-domain
            feat_df['hrv_lf'], feat_df['hrv_hf'], feat_df['hrv_lf'] = np.nan, np.nan, np.nan
            # Time-domain
            feat_df['hrv_rmssd'], feat_df['hrv_sd'], feat_df['hrv_sdsd'], feat_df['hrv_sdnn'] = np.nan, np.nan, np.nan, np.nan
        # If there is enough data, compute HRV features
        # else:
        #   # Frequency-domain

        #   # Time-domain

        feat_PEP = np.squeeze((scg_fid_dict['ao_locs'][scg_fid_dict['flagged_ao']])*1000/FS_RESAMPLE)
        ao_times = np.intersect1d(scg_fid_dict['t_ao'], feat_df.time.values)
        # Add PEP values to df
        for i, ao_time in enumerate(ao_times):
            feat_df.loc[feat_df.time == ao_time, 'pep'] = feat_PEP[i]

        # Get beats with defined AO and AC points
        ac_times = np.intersect1d(scg_fid_dict['t_ac'], feat_df.time.values)
        _, ao_ind, ac_ind = np.intersect1d(ao_times, ac_times, return_indices=True)
        pep_lvet_times = ao_times[ao_ind]
        feat_PEP_LVET = np.squeeze((ao_locs[ao_ind])*1000/FS_RESAMPLE) / np.squeeze((ac_locs[ac_ind])*1000/FS_RESAMPLE)
        # Add PEP/LVET values to df
        for i, pep_lvet_time in enumerate(pep_lvet_times):
            feat_df.loc[feat_df.time == pep_lvet_time, 'pep_lvet'] = feat_PEP_LVET[i]
            
        feat_LVET = np.squeeze((ac_locs[ac_ind])*1000/FS_RESAMPLE) - np.squeeze((ao_locs[ao_ind])*1000/FS_RESAMPLE)
        # Add LVET values to df
        for i, ac_time in enumerate(pep_lvet_times):
            feat_df.loc[feat_df.time == ac_time, 'lvet'] = feat_LVET[i]
            
        ppg_amp_ac = ppg_dict['ppg_amp_ac']
        ppg_amp_ac_dc = ppg_dict['ppg_amp'] # AC amplitude normalized by DC (in case of changes in contact pressure)
        t_ppg_amp = ppg_dict['t_ppg_amp']
        # Add PPG amplitude values to df
        for i, ppg_amp_time in enumerate(t_ppg_amp):
            feat_df.loc[feat_df.time == ppg_amp_time, 'ppg_amp_ac'] = ppg_amp_ac[i]
            feat_df.loc[feat_df.time == ppg_amp_time, 'ppg_amp'] = ppg_amp_ac_dc[i]
            
        feat_PAT = ppg_fid_dict['pulse_locs']
        t_pat = ppg_fid_dict['t_pulse']
        # Add PAT values to df
        for i, pat_time in enumerate(t_pat):
            feat_df.loc[feat_df.time == pat_time, 'pat'] = feat_PAT[i]

        # Find overlapping beats with PAT and PEP values for PTT
        _, pat_ind, pep_ind = np.intersect1d(t_pat, ao_times, return_indices=True)
        pat_for_ptt = feat_PAT[pat_ind]
        pep_for_ptt = feat_PEP[pep_ind]
        feat_PTT = pat_for_ptt - pep_for_ptt
        t_ptt = t_pat[pat_ind]
        # Add PTT values to df
        for i, ptt_time in enumerate(t_ptt):
            feat_df.loc[feat_df.time == ptt_time, 'ptt'] = feat_PTT[i]
            
        # print(feat_df)

        f, ax = plt.subplots(3, 1, figsize = (16, 6), sharex = True)

        # Plot r-peak (ecg) features
        r_peak_idx = [np.argmin(np.abs(activity['time'] - rpeak_i)) for rpeak_i in feat_df['time']]
        ax[0].plot(activity['time'], activity['ecg'], color='salmon')
        ax[0].scatter(feat_df['time'], activity['ecg'][r_peak_idx], color = 'tab:blue', label = 'R-peak')
        ax[0].legend()
        ax[0].set_ylabel('ecg')

        # Plot ao (scg) features
        ao_loc = feat_df['time'] + feat_df['pep']/1000
        ao_idx = [np.argmin(np.abs(activity['time'] - ao_loc_i)) for ao_loc_i in ao_loc]
        ax[1].plot(activity['time'], activity['scg_DV'], color='teal')
        ax[1].scatter(feat_df['time'] + feat_df['pep']/1000, activity['scg_DV'][ao_idx], color = 'tab:orange', label = 'AO')


        # Plot ac (scg) features
        ac_loc = feat_df['time'] + (feat_df['lvet'] +  feat_df['pep'])/1000
        ac_idx = [np.argmin(np.abs(activity['time'] - ac_loc_i)) for ac_loc_i in (ac_loc)]
        ax[1].scatter(ac_loc, activity['scg_DV'][ac_idx], color = 'tab:purple', label = 'AC')
        ax[1].set_ylim([-0.1, 0.1])
        ax[1].legend()
        ax[1].set_ylabel('scg')

        # Plot pat (ppg) features
        if 'pat' in feat_df:
            pat_loc = feat_df['time'] + feat_df['pat']/1000
            pat_idx = [np.argmin(np.abs(activity['time'] - pat_loc_i)) for pat_loc_i in (pat_loc)]
            ax[2].plot(activity['time'], activity[ppg_wavelen+ppg_arr], color='darkgreen')
            ax[2].scatter(pat_loc, activity[ppg_wavelen+ppg_arr][pat_idx], color = 'k', label = 'ppg foot')
            ax[2].set_ylim([-200, 200])
            ax[2].legend()
            ax[2].set_ylabel('ppg')
            ax[2].set_xlabel('Time (s)')
        
        plt.savefig(fig_dir + "r_ao_ac_ppgfoot.png")
        if show_plots:
            plt.show()
        
        # if 'pat' in feat_df:    
        #     feats_to_plot = ['hr', 'pep', 'lvet', 'pep_lvet', 'ppg_amp_ac', 'pat', 'ptt']
        # else:
        #     feats_to_plot = ['hr', 'pep', 'lvet', 'pep_lvet', 'ppg_amp_ac', 'ptt']

        # feat_units = ['bpm', 'ms', 'ms', 'a.u.', 'uW', 'ms', 'ms']
        # colors = sns.color_palette(palette='Set2', n_colors=len(feats_to_plot))
        # fig, axs = plt.subplots(len(feats_to_plot), 1, sharex=True, figsize=(16,14))
        # for ax, feat, unit, col in zip(axs, feats_to_plot, feat_units, colors):
        #     ax.scatter(feat_df.time, feat_df.loc[:,feat], label=feat, color=col)
        #     ax.set_ylabel(unit)
        #     ax.legend(loc='upper right')
        # plt.xlabel('Time (s)')
        
        # plt.savefig(fig_dir + "features.png")
        # plt.show()
        
        feat_df.to_csv(out+f'output_features.csv', index = False)
# Out:
# Subject: 3161
# Activity: prep
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (191)
#    Martinez (192)
#    Kalidas (191)
#    Common (191)
# 187 NN intervals detected from 191 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 21 out of 187
# Stage 2: Moving window MAD removed 5 out of 166
# Stage 3: Moving window DTW removed 41 out of 161
# Stage 4: Global DTW fusion removed 37 out of 161
# Final: Using 153 beats out of 187
# Begin processing SCG...
# Stage 1: Global MAD removed 5 out of 187
# Stage 2: Moving window MAD removed 1 out of 182
# Stage 3: Moving window DTFM removed 43 out of 181
# Stage 4: Global DTFM removed 0 out of 181
# Final: Using 181 beats out of 187
# Engine started...
# Least deviation ao_loc=3
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Activity: recovery
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (1880)
#    Martinez (1880)
#    Kalidas (1880)
#    Common (1880)
# 1838 NN intervals detected from 1880 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 185 out of 1838
# Stage 2: Moving window MAD removed 14 out of 1653
# Stage 3: Moving window DTW removed 1470 out of 1639
# Stage 4: Global DTW fusion removed 1412 out of 1639
# Final: Using 1525 beats out of 1838
# Begin processing SCG...
# Stage 1: Global MAD removed 121 out of 1838
# Stage 2: Moving window MAD removed 34 out of 1717
# Stage 3: Moving window DTFM removed 21 out of 1683
# Stage 4: Global DTFM removed 8 out of 1683
# Final: Using 1662 beats out of 1838
# Engine started...
# Least deviation ao_loc=3
# Least deviation ac_loc=0
# Activity: rest_2
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (2282)
#    Martinez (2282)
#    Kalidas (2282)
#    Common (2281)
# 2138 NN intervals detected from 2281 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 234 out of 2138
# Stage 2: Moving window MAD removed 24 out of 1904
# Stage 3: Moving window DTW removed 1282 out of 1880
# Stage 4: Global DTW fusion removed 1096 out of 1880
# Final: Using 1671 beats out of 2138
# Begin processing SCG...
# Stage 1: Global MAD removed 125 out of 2138
# Stage 2: Moving window MAD removed 51 out of 2013
# Stage 3: Moving window DTFM removed 15 out of 1962
# Stage 4: Global DTFM removed 4 out of 1962
# Final: Using 1947 beats out of 2138
# /tmp/ipykernel_3981072/1820057131.py:97: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(12, 6))
# Engine started...
# Least deviation ao_loc=3
# Least deviation ac_loc=0
# Activity: script
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (194)
#    Martinez (194)
#    Kalidas (194)
#    Common (193)
# 190 NN intervals detected from 193 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 16 out of 190
# Stage 2: Moving window MAD removed 1 out of 174
# Stage 3: Moving window DTW removed 163 out of 173
# Stage 4: Global DTW fusion removed 84 out of 173
# Final: Using 173 beats out of 190
# Begin processing SCG...
# Stage 1: Global MAD removed 8 out of 190
# Stage 2: Moving window MAD removed 1 out of 182
# Stage 3: Moving window DTFM removed 57 out of 181
# Stage 4: Global DTFM removed 2 out of 181
# Final: Using 179 beats out of 190
# Engine started...
# Least deviation ao_loc=1
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Activity: speaking
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (284)
#    Martinez (284)
#    Kalidas (284)
#    Common (284)
# 277 NN intervals detected from 284 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 24 out of 277
# Stage 2: Moving window MAD removed 4 out of 253
# Stage 3: Moving window DTW removed 194 out of 249
# Stage 4: Global DTW fusion removed 111 out of 249
# Final: Using 243 beats out of 277
# Begin processing SCG...
# Stage 1: Global MAD removed 4 out of 277
# Stage 2: Moving window MAD removed 2 out of 273
# Stage 3: Moving window DTFM removed 70 out of 271
# Stage 4: Global DTFM removed 1 out of 271
# Final: Using 270 beats out of 277
# Engine started...
# Least deviation ao_loc=1
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Subject: 3146
# Activity: prep
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (158)
#    Martinez (158)
#    Kalidas (158)
#    Common (158)
# 155 NN intervals detected from 158 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 14 out of 155
# Stage 2: Moving window MAD removed 5 out of 141
# Stage 3: Moving window DTW removed 1 out of 136
# Stage 4: Global DTW fusion removed 2 out of 136
# Final: Using 135 beats out of 155
# Begin processing SCG...
# Stage 1: Global MAD removed 9 out of 155
# Stage 2: Moving window MAD removed 0 out of 146
# Stage 3: Moving window DTFM removed 0 out of 146
# Stage 4: Global DTFM removed 0 out of 146
# Final: Using 146 beats out of 155
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=2
# Not enough data for HRV analysis
# Activity: recovery
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (1811)
#    Martinez (1811)
#    Kalidas (1811)
#    Common (1811)
# 1810 NN intervals detected from 1811 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 187 out of 1810
# Stage 2: Moving window MAD removed 72 out of 1623
# Stage 3: Moving window DTW removed 37 out of 1551
# Stage 4: Global DTW fusion removed 83 out of 1551
# Final: Using 1514 beats out of 1810
# Begin processing SCG...
# Stage 1: Global MAD removed 218 out of 1810
# Stage 2: Moving window MAD removed 11 out of 1592
# Stage 3: Moving window DTFM removed 32 out of 1581
# Stage 4: Global DTFM removed 23 out of 1581
# Final: Using 1549 beats out of 1810
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=0
# Activity: rest_2
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (1586)
#    Martinez (1587)
#    Kalidas (1586)
#    Common (1586)
# 1570 NN intervals detected from 1586 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 186 out of 1570
# Stage 2: Moving window MAD removed 98 out of 1384
# Stage 3: Moving window DTW removed 97 out of 1286
# Stage 4: Global DTW fusion removed 111 out of 1286
# Final: Using 1245 beats out of 1570
# Begin processing SCG...
# Stage 1: Global MAD removed 97 out of 1570
# Stage 2: Moving window MAD removed 12 out of 1473
# Stage 3: Moving window DTFM removed 8 out of 1461
# Stage 4: Global DTFM removed 11 out of 1461
# Final: Using 1453 beats out of 1570
# Engine started...
# Least deviation ao_loc=3
# Least deviation ac_loc=1
# Activity: script
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (153)
#    Martinez (154)
#    Kalidas (153)
#    Common (153)
# 152 NN intervals detected from 153 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 13 out of 152
# Stage 2: Moving window MAD removed 6 out of 139
# Stage 3: Moving window DTW removed 2 out of 133
# Stage 4: Global DTW fusion removed 1 out of 133
# Final: Using 133 beats out of 152
# Begin processing SCG...
# Stage 1: Global MAD removed 5 out of 152
# Stage 2: Moving window MAD removed 1 out of 147
# Stage 3: Moving window DTFM removed 0 out of 146
# Stage 4: Global DTFM removed 0 out of 146
# Final: Using 146 beats out of 152
# Engine started...
# Least deviation ao_loc=1
# Least deviation ac_loc=2
# Not enough data for HRV analysis
# Activity: speaking
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (230)
#    Martinez (231)
#    Kalidas (230)
#    Common (230)
# 228 NN intervals detected from 230 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 35 out of 228
# Stage 2: Moving window MAD removed 27 out of 193
# Stage 3: Moving window DTW removed 0 out of 166
# Stage 4: Global DTW fusion removed 0 out of 166
# Final: Using 166 beats out of 228
# Begin processing SCG...
# Stage 1: Global MAD removed 0 out of 228
# Stage 2: Moving window MAD removed 3 out of 228
# Stage 3: Moving window DTFM removed 0 out of 225
# Stage 4: Global DTFM removed 0 out of 225
# Final: Using 225 beats out of 228
# Engine started...
# Least deviation ao_loc=3
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Subject: 3128
# Activity: prep
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (140)
#    Martinez (140)
#    Kalidas (142)
#    Common (140)
# 139 NN intervals detected from 140 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 22 out of 139
# Stage 2: Moving window MAD removed 6 out of 117
# Stage 3: Moving window DTW removed 22 out of 111
# Stage 4: Global DTW fusion removed 12 out of 111
# Final: Using 111 beats out of 139
# Begin processing SCG...
# Stage 1: Global MAD removed 5 out of 139
# Stage 2: Moving window MAD removed 10 out of 134
# Stage 3: Moving window DTFM removed 5 out of 124
# Stage 4: Global DTFM removed 2 out of 124
# Final: Using 119 beats out of 139
# Engine started...
# Least deviation ao_loc=3
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Activity: recovery
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (1231)
#    Martinez (1230)
#    Kalidas (1231)
#    Common (1228)
# 1078 NN intervals detected from 1228 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 138 out of 1078
# Stage 2: Moving window MAD removed 38 out of 940
# Stage 3: Moving window DTW removed 4 out of 902
# Stage 4: Global DTW fusion removed 3 out of 902
# Final: Using 901 beats out of 1078
# Begin processing SCG...
# Stage 1: Global MAD removed 79 out of 1078
# Stage 2: Moving window MAD removed 11 out of 999
# Stage 3: Moving window DTFM removed 0 out of 988
# Stage 4: Global DTFM removed 0 out of 988
# Final: Using 988 beats out of 1078
# Engine started...
# Least deviation ao_loc=3
# Least deviation ac_loc=1
# Activity: rest_2
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (1435)
#    Martinez (1436)
#    Kalidas (1435)
#    Common (1434)
# 1419 NN intervals detected from 1434 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 221 out of 1419
# Stage 2: Moving window MAD removed 54 out of 1198
# Stage 3: Moving window DTW removed 190 out of 1144
# Stage 4: Global DTW fusion removed 109 out of 1144
# Final: Using 1134 beats out of 1419
# Begin processing SCG...
# Stage 1: Global MAD removed 302 out of 1419
# Stage 2: Moving window MAD removed 53 out of 1117
# Stage 3: Moving window DTFM removed 46 out of 1064
# Stage 4: Global DTFM removed 28 out of 1064
# Final: Using 1018 beats out of 1419
# Engine started...
# Least deviation ao_loc=3
# Least deviation ac_loc=0
# Activity: script
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (135)
#    Martinez (135)
#    Kalidas (135)
#    Common (135)
# 134 NN intervals detected from 135 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 10 out of 134
# Stage 2: Moving window MAD removed 8 out of 124
# Stage 3: Moving window DTW removed 1 out of 116
# Stage 4: Global DTW fusion removed 1 out of 116
# Final: Using 116 beats out of 134
# Begin processing SCG...
# Stage 1: Global MAD removed 10 out of 134
# Stage 2: Moving window MAD removed 6 out of 124
# Stage 3: Moving window DTFM removed 1 out of 118
# Stage 4: Global DTFM removed 1 out of 118
# Final: Using 117 beats out of 134
# Engine started...
# Least deviation ao_loc=1
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Activity: speaking
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (178)
#    Martinez (178)
#    Kalidas (178)
#    Common (178)
# 173 NN intervals detected from 178 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 11 out of 173
# Stage 2: Moving window MAD removed 5 out of 162
# Stage 3: Moving window DTW removed 0 out of 157
# Stage 4: Global DTW fusion removed 0 out of 157
# Final: Using 157 beats out of 173
# Begin processing SCG...
# Stage 1: Global MAD removed 7 out of 173
# Stage 2: Moving window MAD removed 0 out of 166
# Stage 3: Moving window DTFM removed 0 out of 166
# Stage 4: Global DTFM removed 0 out of 166
# Final: Using 166 beats out of 173
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Subject: 3140
# Activity: prep
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (176)
#    Martinez (175)
#    Kalidas (176)
#    Common (176)
# 173 NN intervals detected from 176 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 19 out of 173
# Stage 2: Moving window MAD removed 1 out of 154
# Stage 3: Moving window DTW removed 1 out of 153
# Stage 4: Global DTW fusion removed 1 out of 153
# Final: Using 153 beats out of 173
# Begin processing SCG...
# Stage 1: Global MAD removed 9 out of 173
# Stage 2: Moving window MAD removed 5 out of 164
# Stage 3: Moving window DTFM removed 1 out of 159
# Stage 4: Global DTFM removed 1 out of 159
# Final: Using 158 beats out of 173
# Engine started...
# Least deviation ao_loc=2
# Least deviation ac_loc=1
# Not enough data for HRV analysis
# Activity: recovery
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (1793)
#    Martinez (1789)
#    Kalidas (1795)
#    Common (1789)
# 1781 NN intervals detected from 1789 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 193 out of 1781
# Stage 2: Moving window MAD removed 34 out of 1588
# Stage 3: Moving window DTW removed 172 out of 1554
# Stage 4: Global DTW fusion removed 142 out of 1554
# Final: Using 1528 beats out of 1781
# Begin processing SCG...
# Stage 1: Global MAD removed 152 out of 1781
# Stage 2: Moving window MAD removed 42 out of 1629
# Stage 3: Moving window DTFM removed 93 out of 1587
# Stage 4: Global DTFM removed 15 out of 1587
# Final: Using 1494 beats out of 1781
# Engine started...
# Least deviation ao_loc=2
# Least deviation ac_loc=0
# Activity: rest_2
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (1717)
#    Martinez (1714)
#    Kalidas (1717)
#    Common (1709)
# 1670 NN intervals detected from 1709 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 155 out of 1670
# Stage 2: Moving window MAD removed 33 out of 1515
# Stage 3: Moving window DTW removed 15 out of 1482
# Stage 4: Global DTW fusion removed 11 out of 1482
# Final: Using 1482 beats out of 1670
# Begin processing SCG...
# Stage 1: Global MAD removed 97 out of 1670
# Stage 2: Moving window MAD removed 16 out of 1573
# Stage 3: Moving window DTFM removed 22 out of 1557
# Stage 4: Global DTFM removed 17 out of 1557
# Final: Using 1535 beats out of 1670
# Engine started...
# Least deviation ao_loc=2
# Least deviation ac_loc=2
# Activity: script
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (171)
#    Martinez (171)
#    Kalidas (171)
#    Common (171)
# 168 NN intervals detected from 171 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 22 out of 168
# Stage 2: Moving window MAD removed 2 out of 146
# Stage 3: Moving window DTW removed 0 out of 144
# Stage 4: Global DTW fusion removed 3 out of 144
# Final: Using 144 beats out of 168
# Begin processing SCG...
# Stage 1: Global MAD removed 8 out of 168
# Stage 2: Moving window MAD removed 2 out of 160
# Stage 3: Moving window DTFM removed 3 out of 158
# Stage 4: Global DTFM removed 3 out of 158
# Final: Using 155 beats out of 168
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=1
# Not enough data for HRV analysis
# Activity: speaking
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (257)
#    Martinez (257)
#    Kalidas (257)
#    Common (255)
# 253 NN intervals detected from 255 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 29 out of 253
# Stage 2: Moving window MAD removed 7 out of 224
# Stage 3: Moving window DTW removed 1 out of 217
# Stage 4: Global DTW fusion removed 2 out of 217
# Final: Using 216 beats out of 253
# Begin processing SCG...
# Stage 1: Global MAD removed 13 out of 253
# Stage 2: Moving window MAD removed 3 out of 240
# Stage 3: Moving window DTFM removed 1 out of 237
# Stage 4: Global DTFM removed 0 out of 237
# Final: Using 236 beats out of 253
# Engine started...
# Least deviation ao_loc=3
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Subject: 3157
# Activity: prep
# /home/michael/miniconda3/envs/mims-transformer-stress-classification/lib/python3.11/site-packages/neurokit2/signal/signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (199)
#    Martinez (2)
#    Kalidas (198)
#    Common (122)
# 80 NN intervals detected from 122 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 9 out of 80
# Stage 2: Moving window MAD removed 0 out of 71
# Stage 3: Moving window DTW removed 0 out of 71
# Stage 4: Global DTW fusion removed 0 out of 71
# Final: Using 71 beats out of 80
# Begin processing SCG...
# Stage 1: Global MAD removed 0 out of 80
# Stage 2: Moving window MAD removed 0 out of 80
# Stage 3: Moving window DTFM removed 0 out of 80
# Stage 4: Global DTFM removed 0 out of 80
# Final: Using 80 beats out of 80
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Activity: recovery
# Number of peaks found:
#    Neurokit (1872)
#    Martinez (1872)
#    Kalidas (1872)
#    Common (1854)
# 1619 NN intervals detected from 1854 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 179 out of 1619
# Stage 2: Moving window MAD removed 30 out of 1440
# Stage 3: Moving window DTW removed 51 out of 1410
# Stage 4: Global DTW fusion removed 41 out of 1410
# Final: Using 1400 beats out of 1619
# Begin processing SCG...
# Stage 1: Global MAD removed 99 out of 1619
# Stage 2: Moving window MAD removed 17 out of 1520
# Stage 3: Moving window DTFM removed 4 out of 1503
# Stage 4: Global DTFM removed 4 out of 1503
# Final: Using 1499 beats out of 1619
# Engine started...
# Least deviation ao_loc=3
# Least deviation ac_loc=1
# Activity: rest_2
# Number of peaks found:
#    Neurokit (1731)
#    Martinez (1732)
#    Kalidas (1731)
#    Common (1708)
# 1684 NN intervals detected from 1708 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 216 out of 1684
# Stage 2: Moving window MAD removed 38 out of 1468
# Stage 3: Moving window DTW removed 1 out of 1430
# Stage 4: Global DTW fusion removed 3 out of 1430
# Final: Using 1429 beats out of 1684
# Begin processing SCG...
# Stage 1: Global MAD removed 41 out of 1684
# Stage 2: Moving window MAD removed 36 out of 1643
# Stage 3: Moving window DTFM removed 2 out of 1607
# Stage 4: Global DTFM removed 2 out of 1607
# Final: Using 1605 beats out of 1684
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=2
# Activity: script
# Number of peaks found:
#    Neurokit (184)
#    Martinez (184)
#    Kalidas (184)
#    Common (176)
# 166 NN intervals detected from 176 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 15 out of 166
# Stage 2: Moving window MAD removed 1 out of 151
# Stage 3: Moving window DTW removed 5 out of 150
# Stage 4: Global DTW fusion removed 6 out of 150
# Final: Using 149 beats out of 166
# Begin processing SCG...
# Stage 1: Global MAD removed 10 out of 166
# Stage 2: Moving window MAD removed 3 out of 156
# Stage 3: Moving window DTFM removed 0 out of 153
# Stage 4: Global DTFM removed 1 out of 153
# Final: Using 153 beats out of 166
# Engine started...
# Least deviation ao_loc=1
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Activity: speaking
# Number of peaks found:
#    Neurokit (317)
#    Martinez (317)
#    Kalidas (317)
#    Common (317)
# 312 NN intervals detected from 317 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 38 out of 312
# Stage 2: Moving window MAD removed 3 out of 274
# Stage 3: Moving window DTW removed 85 out of 271
# Stage 4: Global DTW fusion removed 71 out of 271
# Final: Using 251 beats out of 312
# Begin processing SCG...
# Stage 1: Global MAD removed 20 out of 312
# Stage 2: Moving window MAD removed 2 out of 292
# Stage 3: Moving window DTFM removed 8 out of 290
# Stage 4: Global DTFM removed 9 out of 290
# Final: Using 282 beats out of 312
# Engine started...
# Least deviation ao_loc=1
# Least deviation ac_loc=1
# Not enough data for HRV analysis
# Subject: 3142
# Activity: prep
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (129)
#    Martinez (130)
#    Kalidas (129)
#    Common (129)
# 128 NN intervals detected from 129 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 20 out of 128
# Stage 2: Moving window MAD removed 15 out of 108
# Stage 3: Moving window DTW removed 1 out of 93
# Stage 4: Global DTW fusion removed 5 out of 93
# Final: Using 92 beats out of 128
# Begin processing SCG...
# Stage 1: Global MAD removed 12 out of 128
# Stage 2: Moving window MAD removed 6 out of 116
# Stage 3: Moving window DTFM removed 2 out of 110
# Stage 4: Global DTFM removed 0 out of 110
# Final: Using 108 beats out of 128
# Engine started...
# Least deviation ao_loc=2
# Least deviation ac_loc=2
# Not enough data for HRV analysis
# Activity: recovery
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (1318)
#    Martinez (1318)
#    Kalidas (1319)
#    Common (1318)
# 1317 NN intervals detected from 1318 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 146 out of 1317
# Stage 2: Moving window MAD removed 106 out of 1171
# Stage 3: Moving window DTW removed 46 out of 1065
# Stage 4: Global DTW fusion removed 28 out of 1065
# Final: Using 1064 beats out of 1317
# Begin processing SCG...
# Stage 1: Global MAD removed 213 out of 1317
# Stage 2: Moving window MAD removed 21 out of 1104
# Stage 3: Moving window DTFM removed 14 out of 1083
# Stage 4: Global DTFM removed 16 out of 1083
# Final: Using 1069 beats out of 1317
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=2
# Activity: rest_2
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (1411)
#    Martinez (1411)
#    Kalidas (1412)
#    Common (1411)
# 1345 NN intervals detected from 1411 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 262 out of 1345
# Stage 2: Moving window MAD removed 79 out of 1083
# Stage 3: Moving window DTW removed 17 out of 1004
# Stage 4: Global DTW fusion removed 9 out of 1004
# Final: Using 1004 beats out of 1345
# Begin processing SCG...
# Stage 1: Global MAD removed 63 out of 1345
# Stage 2: Moving window MAD removed 11 out of 1282
# Stage 3: Moving window DTFM removed 3 out of 1271
# Stage 4: Global DTFM removed 3 out of 1271
# Final: Using 1268 beats out of 1345
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=2
# Activity: script
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (129)
#    Martinez (129)
#    Kalidas (129)
#    Common (129)
# 127 NN intervals detected from 129 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 30 out of 127
# Stage 2: Moving window MAD removed 9 out of 97
# Stage 3: Moving window DTW removed 0 out of 88
# Stage 4: Global DTW fusion removed 0 out of 88
# Final: Using 88 beats out of 127
# Begin processing SCG...
# Stage 1: Global MAD removed 9 out of 127
# Stage 2: Moving window MAD removed 1 out of 118
# Stage 3: Moving window DTFM removed 4 out of 117
# Stage 4: Global DTFM removed 5 out of 117
# Final: Using 113 beats out of 127
# Engine started...
# Least deviation ao_loc=1
# Least deviation ac_loc=1
# Not enough data for HRV analysis
# Activity: speaking
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (201)
#    Martinez (201)
#    Kalidas (201)
#    Common (201)
# 196 NN intervals detected from 201 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 26 out of 196
# Stage 2: Moving window MAD removed 8 out of 170
# Stage 3: Moving window DTW removed 0 out of 162
# Stage 4: Global DTW fusion removed 0 out of 162
# Final: Using 162 beats out of 196
# Begin processing SCG...
# Stage 1: Global MAD removed 8 out of 196
# Stage 2: Moving window MAD removed 0 out of 188
# Stage 3: Moving window DTFM removed 2 out of 188
# Stage 4: Global DTFM removed 3 out of 188
# Final: Using 186 beats out of 196
# Engine started...
# Least deviation ao_loc=2
# Least deviation ac_loc=2
# Not enough data for HRV analysis
# Subject: 3147
# Activity: prep
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (106)
#    Martinez (106)
#    Kalidas (106)
#    Common (106)
# 105 NN intervals detected from 106 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 17 out of 105
# Stage 2: Moving window MAD removed 5 out of 88
# Stage 3: Moving window DTW removed 4 out of 83
# Stage 4: Global DTW fusion removed 5 out of 83
# Final: Using 82 beats out of 105
# Begin processing SCG...
# Stage 1: Global MAD removed 0 out of 105
# Stage 2: Moving window MAD removed 0 out of 105
# Stage 3: Moving window DTFM removed 0 out of 105
# Stage 4: Global DTFM removed 0 out of 105
# Final: Using 105 beats out of 105
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Activity: recovery
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (1113)
#    Martinez (1113)
#    Kalidas (1113)
#    Common (1108)
# 832 NN intervals detected from 1108 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 159 out of 832
# Stage 2: Moving window MAD removed 69 out of 673
# Stage 3: Moving window DTW removed 40 out of 604
# Stage 4: Global DTW fusion removed 52 out of 604
# Final: Using 589 beats out of 832
# Begin processing SCG...
# Stage 1: Global MAD removed 33 out of 832
# Stage 2: Moving window MAD removed 18 out of 799
# Stage 3: Moving window DTFM removed 25 out of 781
# Stage 4: Global DTFM removed 9 out of 781
# Final: Using 756 beats out of 832
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=2
# Activity: rest_2
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (1011)
#    Martinez (1011)
#    Kalidas (1011)
#    Common (1011)
# 992 NN intervals detected from 1011 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 201 out of 992
# Stage 2: Moving window MAD removed 67 out of 791
# Stage 3: Moving window DTW removed 18 out of 724
# Stage 4: Global DTW fusion removed 24 out of 724
# Final: Using 714 beats out of 992
# Begin processing SCG...
# Stage 1: Global MAD removed 14 out of 992
# Stage 2: Moving window MAD removed 24 out of 978
# Stage 3: Moving window DTFM removed 2 out of 954
# Stage 4: Global DTFM removed 2 out of 954
# Final: Using 952 beats out of 992
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=2
# Activity: script
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (110)
#    Martinez (110)
#    Kalidas (110)
#    Common (110)
# 96 NN intervals detected from 110 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 10 out of 96
# Stage 2: Moving window MAD removed 5 out of 86
# Stage 3: Moving window DTW removed 17 out of 81
# Stage 4: Global DTW fusion removed 21 out of 81
# Final: Using 77 beats out of 96
# Begin processing SCG...
# Stage 1: Global MAD removed 4 out of 96
# Stage 2: Moving window MAD removed 6 out of 92
# Stage 3: Moving window DTFM removed 2 out of 86
# Stage 4: Global DTFM removed 3 out of 86
# Final: Using 84 beats out of 96
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=2
# Not enough data for HRV analysis
# Activity: speaking
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (173)
#    Martinez (173)
#    Kalidas (174)
#    Common (172)
# 160 NN intervals detected from 172 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 23 out of 160
# Stage 2: Moving window MAD removed 9 out of 137
# Stage 3: Moving window DTW removed 2 out of 128
# Stage 4: Global DTW fusion removed 2 out of 128
# Final: Using 128 beats out of 160
# Begin processing SCG...
# Stage 1: Global MAD removed 1 out of 160
# Stage 2: Moving window MAD removed 0 out of 159
# Stage 3: Moving window DTFM removed 1 out of 159
# Stage 4: Global DTFM removed 0 out of 159
# Final: Using 158 beats out of 160
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=2
# Not enough data for HRV analysis
# Subject: 3138
# Activity: prep
# Number of peaks found:
#    Neurokit (101)
#    Martinez (28)
#    Kalidas (97)
#    Common (95)
# 46 NN intervals detected from 95 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 7 out of 46
# Stage 2: Moving window MAD removed 2 out of 39
# Stage 3: Moving window DTW removed 0 out of 37
# Stage 4: Global DTW fusion removed 1 out of 37
# Final: Using 37 beats out of 46
# Begin processing SCG...
# Stage 1: Global MAD removed 2 out of 46
# Stage 2: Moving window MAD removed 0 out of 44
# Stage 3: Moving window DTFM removed 0 out of 44
# Stage 4: Global DTFM removed 1 out of 44
# Final: Using 44 beats out of 46
# Engine started...
# Least deviation ao_loc=1
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Activity: recovery
# Number of peaks found:
#    Neurokit (1195)
#    Martinez (343)
#    Kalidas (1097)
#    Common (1180)
# 1032 NN intervals detected from 1180 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 159 out of 1032
# Stage 2: Moving window MAD removed 44 out of 873
# Stage 3: Moving window DTW removed 55 out of 829
# Stage 4: Global DTW fusion removed 43 out of 829
# Final: Using 823 beats out of 1032
# Begin processing SCG...
# Stage 1: Global MAD removed 39 out of 1032
# Stage 2: Moving window MAD removed 19 out of 993
# Stage 3: Moving window DTFM removed 8 out of 974
# Stage 4: Global DTFM removed 23 out of 974
# Final: Using 966 beats out of 1032
# Engine started...
# Least deviation ao_loc=3
# Least deviation ac_loc=0
# Activity: rest_2
# Number of peaks found:
#    Neurokit (985)
#    Martinez (272)
#    Kalidas (890)
#    Common (879)
# 384 NN intervals detected from 879 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 55 out of 384
# Stage 2: Moving window MAD removed 8 out of 329
# Stage 3: Moving window DTW removed 41 out of 321
# Stage 4: Global DTW fusion removed 36 out of 321
# Final: Using 315 beats out of 384
# Begin processing SCG...
# Stage 1: Global MAD removed 21 out of 384
# Stage 2: Moving window MAD removed 7 out of 363
# Stage 3: Moving window DTFM removed 3 out of 356
# Stage 4: Global DTFM removed 4 out of 356
# Final: Using 353 beats out of 384
# Engine started...
# Least deviation ao_loc=2
# Least deviation ac_loc=0
# Activity: script
# Number of peaks found:
#    Neurokit (102)
#    Martinez (26)
#    Kalidas (99)
#    Common (99)
# 53 NN intervals detected from 99 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 6 out of 53
# Stage 2: Moving window MAD removed 4 out of 47
# Stage 3: Moving window DTW removed 1 out of 43
# Stage 4: Global DTW fusion removed 1 out of 43
# Final: Using 43 beats out of 53
# Begin processing SCG...
# Stage 1: Global MAD removed 5 out of 53
# Stage 2: Moving window MAD removed 0 out of 48
# Stage 3: Moving window DTFM removed 0 out of 48
# Stage 4: Global DTFM removed 0 out of 48
# Final: Using 48 beats out of 53
# Engine started...
# Least deviation ao_loc=2
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Activity: speaking
# Number of peaks found:
#    Neurokit (168)
#    Martinez (45)
#    Kalidas (168)
#    Common (163)
# 148 NN intervals detected from 163 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 24 out of 148
# Stage 2: Moving window MAD removed 0 out of 124
# Stage 3: Moving window DTW removed 7 out of 124
# Stage 4: Global DTW fusion removed 5 out of 124
# Final: Using 124 beats out of 148
# Begin processing SCG...
# Stage 1: Global MAD removed 1 out of 148
# Stage 2: Moving window MAD removed 0 out of 147
# Stage 3: Moving window DTFM removed 0 out of 147
# Stage 4: Global DTFM removed 0 out of 147
# Final: Using 147 beats out of 148
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Subject: 3152
# Activity: prep
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (143)
#    Martinez (143)
#    Kalidas (143)
#    Common (143)
# 142 NN intervals detected from 143 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 27 out of 142
# Stage 2: Moving window MAD removed 9 out of 115
# Stage 3: Moving window DTW removed 0 out of 106
# Stage 4: Global DTW fusion removed 0 out of 106
# Final: Using 106 beats out of 142
# Begin processing SCG...
# Stage 1: Global MAD removed 5 out of 142
# Stage 2: Moving window MAD removed 2 out of 137
# Stage 3: Moving window DTFM removed 0 out of 135
# Stage 4: Global DTFM removed 1 out of 135
# Final: Using 135 beats out of 142
# Engine started...
# Least deviation ao_loc=1
# Least deviation ac_loc=0
# Not enough data for HRV analysis
# Activity: recovery
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (1257)
#    Martinez (1257)
#    Kalidas (1257)
#    Common (1257)
# 1199 NN intervals detected from 1257 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 279 out of 1199
# Stage 2: Moving window MAD removed 26 out of 920
# Stage 3: Moving window DTW removed 2 out of 894
# Stage 4: Global DTW fusion removed 1 out of 894
# Final: Using 894 beats out of 1199
# Begin processing SCG...
# Stage 1: Global MAD removed 88 out of 1199
# Stage 2: Moving window MAD removed 15 out of 1111
# Stage 3: Moving window DTFM removed 4 out of 1096
# Stage 4: Global DTFM removed 5 out of 1096
# Final: Using 1092 beats out of 1199
# Engine started...
# Least deviation ao_loc=1
# Least deviation ac_loc=2
# Activity: rest_2
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (1241)
#    Martinez (1241)
#    Kalidas (1241)
#    Common (1241)
# 1227 NN intervals detected from 1241 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 210 out of 1227
# Stage 2: Moving window MAD removed 42 out of 1017
# Stage 3: Moving window DTW removed 0 out of 975
# Stage 4: Global DTW fusion removed 0 out of 975
# Final: Using 975 beats out of 1227
# Begin processing SCG...
# Stage 1: Global MAD removed 21 out of 1227
# Stage 2: Moving window MAD removed 6 out of 1206
# Stage 3: Moving window DTFM removed 1 out of 1200
# Stage 4: Global DTFM removed 2 out of 1200
# Final: Using 1199 beats out of 1227
# Engine started...
# Least deviation ao_loc=3
# Least deviation ac_loc=2
# Activity: script
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (127)
#    Martinez (127)
#    Kalidas (127)
#    Common (127)
# 126 NN intervals detected from 127 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 16 out of 126
# Stage 2: Moving window MAD removed 10 out of 110
# Stage 3: Moving window DTW removed 0 out of 100
# Stage 4: Global DTW fusion removed 0 out of 100
# Final: Using 100 beats out of 126
# Begin processing SCG...
# Stage 1: Global MAD removed 2 out of 126
# Stage 2: Moving window MAD removed 2 out of 124
# Stage 3: Moving window DTFM removed 0 out of 122
# Stage 4: Global DTFM removed 0 out of 122
# Final: Using 122 beats out of 126
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=2
# Not enough data for HRV analysis
# Activity: speaking
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (210)
#    Martinez (211)
#    Kalidas (210)
#    Common (210)
# 201 NN intervals detected from 210 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 20 out of 201
# Stage 2: Moving window MAD removed 20 out of 181
# Stage 3: Moving window DTW removed 7 out of 161
# Stage 4: Global DTW fusion removed 7 out of 161
# Final: Using 161 beats out of 201
# Begin processing SCG...
# Stage 1: Global MAD removed 20 out of 201
# Stage 2: Moving window MAD removed 1 out of 181
# Stage 3: Moving window DTFM removed 2 out of 180
# Stage 4: Global DTFM removed 0 out of 180
# Final: Using 178 beats out of 201
# Engine started...
# Least deviation ao_loc=1
# Least deviation ac_loc=1
# Not enough data for HRV analysis
# Subject: 6046
# Activity: prep
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (142)
#    Martinez (142)
#    Kalidas (143)
#    Common (142)
# 138 NN intervals detected from 142 peaks.
# Using PPG array 2
# Begin processing PPG
# Stage 1: Global MAD removed 27 out of 138
# Stage 2: Moving window MAD removed 10 out of 111
# Stage 3: Moving window DTW removed 0 out of 101
# Stage 4: Global DTW fusion removed 0 out of 101
# Final: Using 101 beats out of 138
# Begin processing SCG...
# Stage 1: Global MAD removed 0 out of 138
# Stage 2: Moving window MAD removed 1 out of 138
# Stage 3: Moving window DTFM removed 0 out of 137
# Stage 4: Global DTFM removed 0 out of 137
# Final: Using 137 beats out of 138
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=2
# Not enough data for HRV analysis
# Activity: recovery
# ECG signal was inverted.
# Number of peaks found:
#    Neurokit (1249)
#    Martinez (1249)
#    Kalidas (1249)
#    Common (1249)
# 1236 NN intervals detected from 1249 peaks.
# Using PPG array 1
# Begin processing PPG
# Stage 1: Global MAD removed 129 out of 1236
# Stage 2: Moving window MAD removed 63 out of 1107
# Stage 3: Moving window DTW removed 5 out of 1044
# Stage 4: Global DTW fusion removed 5 out of 1044
# Final: Using 1044 beats out of 1236
# Begin processing SCG...
# Stage 1: Global MAD removed 19 out of 1236
# Stage 2: Moving window MAD removed 33 out of 1217
# Stage 3: Moving window DTFM removed 0 out of 1184
# Stage 4: Global DTFM removed 0 out of 1184
# Final: Using 1184 beats out of 1236
# Engine started...
# Least deviation ao_loc=0
# Least deviation ac_loc=2
# Activity: rest_2
# /home/michael/miniconda3/envs/mims-transformer-stress-classification/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/michael/miniconda3/envs/mims-transformer-stress-classification/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Number of peaks found:
#    Neurokit (1220)
#    Martinez (0)
#    Kalidas (1219)
#    Common (0)
# /home/michael/miniconda3/envs/mims-transformer-stress-classification/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 57
#      54     plt.show()
#      56 # Note we pass the raw ECG here, as we use different R-peak detectors that each require specific filtering
# ---> 57 ecg_dict = process_ECG(activity['ecg'],
#      58                 activity['time'],
#      59                 force_inverse=False,
#      60                 width_QRS=width_QRS,
#      61                 peak_tol=pk_tolerance_ms,
#      62                 beat_len=beat_length,
#      63                 Fs=FS_RESAMPLE,
#      64                 verbose=True,
#      65                 plotFlag=True)
#      67 # PPG Array selection
#      68 ppg_arr,_ = select_ppg_array(activity[ppg_wavelen+'_1'],
#      69                             activity[ppg_wavelen+'_2'],
#      70                             verbose=True)
#
# File ~/Code/mims-transformer-stress-classification/patch/Processing/processECG.py:203, in process_ECG(ecg_raw, time, force_inverse, width_QRS, peak_tol, beat_len, Fs, verbose, plotFlag)
#     200 i_NN, nn_intervals,_ = get_nni_from_rpeaks(i_R_peaks, ecg_inv[i_R_peaks], rmOutliers=True, Fs=Fs)
#     202 # Get ECG beats
# --> 203 ecg_beats, _ = get_beats_fixed_length(ecg_filt, i_NN, nn_intervals, Fs=Fs, beat_len=beat_len, padDC=False)
#     205 if plotFlag:
#     206     _,axs = plt.subplots(2,1, figsize=(20, 10), sharex=True)
#
# File ~/Code/mims-transformer-stress-classification/patch/Tools/segmentation.py:177, in get_beats_fixed_length(signal, i_beats, intervals, Fs, beat_len, padDC)
#     173         beats[i,len(beat):] = np.mean(signal[i_beats[i]:i_beats[i]+beat_int])
#     175 # Handle the last beat (which has no associated interval)
#     176 # Just use last beat interval for this one (likely similar)
# --> 177 last_beat_int = intervals[-1]
#     178 if last_beat_int < beat_len:
#     179     beats[-1, :last_beat_int] = signal[i_beats[-1]:i_beats[-1]+last_beat_int]
#
# IndexError: index -1 is out of bounds for axis 0 with size 0
